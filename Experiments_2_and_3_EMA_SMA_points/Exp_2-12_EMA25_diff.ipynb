# %%
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import importlib
import experiment_utils

importlib.reload(experiment_utils)

from experiment_utils import (
    MLPClassifier,
    run_one_experiment,
    run,
    save_result
)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/Processed_Project_Data/fifa_and_elo_with_ema_v2.csv")

df = df.drop(columns=["Unnamed: 0"], errors="ignore")

df["date"] = pd.to_datetime(df["date"], format="mixed")

df = df.sort_values("date").reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (1239, 49)
#         date             home_team    away_team  home_score  away_score  \
# 0 2022-01-27               Jamaica       Mexico         1.0         2.0
# 1 2022-01-27  United Arab Emirates        Syria         2.0         0.0
# 2 2022-01-27              Honduras       Canada         0.0         2.0
# 3 2022-01-27            Costa Rica       Panama         1.0         0.0
# 4 2022-01-27               Lebanon  South Korea         0.0         1.0
#
#                      tournament            city               country  \
# 0  FIFA World Cup qualification        Kingston               Jamaica
# 1  FIFA World Cup qualification           Dubai  United Arab Emirates
# 2  FIFA World Cup qualification  San Pedro Sula              Honduras
# 3  FIFA World Cup qualification        San José            Costa Rica
# 4  FIFA World Cup qualification           Sidon               Lebanon
#
#    neutral  year  ...  away_form_sma7  away_form_ema50  away_form_ema33  \
# 0        0  2022  ...             NaN              NaN              NaN
# 1        0  2022  ...             NaN              NaN              NaN
# 2        0  2022  ...             NaN              NaN              NaN
# 3        0  2022  ...             NaN              NaN              NaN
# 4        0  2022  ...             NaN              NaN              NaN
#
#   away_form_ema25  form_diff_sma3  form_diff_sma5  form_diff_sma7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    form_diff_ema50  form_diff_ema33 form_diff_ema25
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
#
# [5 rows x 49 columns]

# %%
features = [
    "form_diff_ema25"
]

target = "result"

# %%
print("Broj redova pre uklanjanja NaN vrednosti:", len(df))
print()
print("NaN vrednosti u feature kolonama:")
print(df[features].isna().sum())

df = df.dropna(subset=features + [target]).reset_index(drop=True)

print()
print("Broj redova posle uklanjanja NaN vrednosti:", len(df))
print()
print("Provera NaN vrednosti posle filtriranja:")
print(df[features].isna().sum())

df[features + [target]].head()
# Out:
# Broj redova pre uklanjanja NaN vrednosti: 1239
#
# NaN vrednosti u feature kolonama:
# form_diff_ema25    129
# dtype: int64
#
# Broj redova posle uklanjanja NaN vrednosti: 1110
#
# Provera NaN vrednosti posle filtriranja:
# form_diff_ema25    0
# dtype: int64
#    form_diff_ema25  result
# 0              0.0       0
# 1              0.0       1
# 2              0.0      -1
# 3              0.0       1
# 4              0.0       1

# %%
X = df[features].values

label_map = {
    -1: 0,   # away win
     0: 1,   # draw
     1: 2    # home win
}

y = df[target].map(label_map).values

print("Label mapping:")
print("-1 -> 0  away win")
print(" 0 -> 1  draw")
print(" 1 -> 2  home win")
# Out:
# Label mapping:
# -1 -> 0  away win
#  0 -> 1  draw
#  1 -> 2  home win

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (888, 1)
# X_test: (222, 1)
# y_train: (888,)
# y_test: (222,)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_tensor = torch.tensor(
    X_train_scaled,
    dtype=torch.float32
)

y_train_tensor = torch.tensor(
    y_train,
    dtype=torch.long
)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
)

y_test_tensor = torch.tensor(
    y_test,
    dtype=torch.long
)

print("Tensor shapes:")
print("X_train_tensor:", X_train_tensor.shape)
print("y_train_tensor:", y_train_tensor.shape)
print("X_test_tensor:", X_test_tensor.shape)
print("y_test_tensor:", y_test_tensor.shape)
# Out:
# Tensor shapes:
# X_train_tensor: torch.Size([888, 1])
# y_train_tensor: torch.Size([888])
# X_test_tensor: torch.Size([222, 1])
# y_test_tensor: torch.Size([222])

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

input_dim = X_train_tensor.shape[1]

model = MLPClassifier(input_dim=input_dim)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

# %%
run_one_experiment(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
    batch_size=16,
    num_epochs=1000,
    seed=42,
    validation_fraction=0.2,
    plot_graph=True,
    verbose=True
)
# Out:
# Epoch 50/1000 | train loss = 1.0233 | val loss = 0.9765 | val acc = 0.5843
# Epoch 100/1000 | train loss = 1.0217 | val loss = 0.9842 | val acc = 0.5787
# Epoch 150/1000 | train loss = 1.0190 | val loss = 0.9826 | val acc = 0.5843
# Epoch 200/1000 | train loss = 1.0142 | val loss = 0.9833 | val acc = 0.5787
# Epoch 250/1000 | train loss = 1.0155 | val loss = 0.9818 | val acc = 0.5730
# Epoch 300/1000 | train loss = 1.0174 | val loss = 0.9842 | val acc = 0.5730
# Epoch 350/1000 | train loss = 1.0158 | val loss = 0.9856 | val acc = 0.5730
# Epoch 400/1000 | train loss = 1.0159 | val loss = 0.9837 | val acc = 0.5730
# Epoch 450/1000 | train loss = 1.0156 | val loss = 0.9867 | val acc = 0.5787
# Epoch 500/1000 | train loss = 1.0188 | val loss = 0.9876 | val acc = 0.5787
# Epoch 550/1000 | train loss = 1.0146 | val loss = 0.9832 | val acc = 0.5787
# Epoch 600/1000 | train loss = 1.0140 | val loss = 0.9831 | val acc = 0.5787
# Epoch 650/1000 | train loss = 1.0212 | val loss = 0.9892 | val acc = 0.5730
# Epoch 700/1000 | train loss = 1.0142 | val loss = 0.9808 | val acc = 0.5787
# Epoch 750/1000 | train loss = 1.0150 | val loss = 0.9827 | val acc = 0.5787
# Epoch 800/1000 | train loss = 1.0139 | val loss = 0.9799 | val acc = 0.5787
# Epoch 850/1000 | train loss = 1.0044 | val loss = 0.9831 | val acc = 0.5787
# Epoch 900/1000 | train loss = 1.0115 | val loss = 0.9849 | val acc = 0.5787
# Epoch 950/1000 | train loss = 1.0145 | val loss = 0.9820 | val acc = 0.5787
# Epoch 1000/1000 | train loss = 1.0149 | val loss = 0.9815 | val acc = 0.5787
#
# =========================
# Best epoch:    110
# Best val loss: 0.9746
# Test accuracy: 0.6081
# =========================
# 0.6081081081081081

# %%
best_num_epochs = 110

summary, results_df = run(
    model_class=MLPClassifier,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
    num_runs=10,
    num_epochs=best_num_epochs,
    batch_size=16,
    learning_rate=0.001
)
# Out:
# Run 1/10
# Accuracy: 0.6081 | Precision: 0.3987 | Recall: 0.4951 | Specificity: 0.7675 | F1: 0.4405
#
# Run 2/10
# Accuracy: 0.6126 | Precision: 0.4065 | Recall: 0.4918 | Specificity: 0.7654 | F1: 0.4408
#
# Run 3/10
# Accuracy: 0.6081 | Precision: 0.3988 | Recall: 0.4930 | Specificity: 0.7667 | F1: 0.4393
#
# Run 4/10
# Accuracy: 0.6081 | Precision: 0.4002 | Recall: 0.4930 | Specificity: 0.7658 | F1: 0.4398
#
# Run 5/10
# Accuracy: 0.6081 | Precision: 0.3988 | Recall: 0.4930 | Specificity: 0.7667 | F1: 0.4393
#
# Run 6/10
# Accuracy: 0.6081 | Precision: 0.4002 | Recall: 0.4930 | Specificity: 0.7658 | F1: 0.4398
#
# Run 7/10
# Accuracy: 0.6081 | Precision: 0.3988 | Recall: 0.4930 | Specificity: 0.7667 | F1: 0.4393
#
# Run 8/10
# Accuracy: 0.6126 | Precision: 0.4022 | Recall: 0.4981 | Specificity: 0.7696 | F1: 0.4436
#
# Run 9/10
# Accuracy: 0.6216 | Precision: 0.4087 | Recall: 0.5105 | Specificity: 0.7764 | F1: 0.4534
#
# Run 10/10
# Accuracy: 0.6081 | Precision: 0.3987 | Recall: 0.4951 | Specificity: 0.7675 | F1: 0.4405
#
# =========================
# Summary over all runs
# =========================
# Accuracy:    0.6104
# Precision:   0.4012
# Recall:      0.4956
# Specificity: 0.7678
# F1 mean:     0.4416
# F1 std:      0.0043
# F1 min:      0.4393
# F1 max:      0.4534
# =========================
#
# Classification report for last run:
#               precision    recall  f1-score   support
#
#     Away Win       0.57      0.63      0.60        65
#         Draw       0.00      0.00      0.00        47
#     Home Win       0.63      0.85      0.72       110
#
#     accuracy                           0.61       222
#    macro avg       0.40      0.50      0.44       222
# weighted avg       0.48      0.61      0.53       222
#
# Confusion matrix for last run:
#                Pred Away Win  Pred Draw  Pred Home Win
# True Away Win             41          0             24
# True Draw                 15          0             32
# True Home Win             16          0             94

# %%
save_result(
    experiment_name="Experiment_2-12_v2_points_EMA25_Diff",
    summary=summary
)
# Out:
# Saved result for Experiment_2-12_v2_points_EMA25_Diff
# File: ../results/experiment_summary_final.csv
