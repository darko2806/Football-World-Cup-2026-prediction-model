# %%
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import importlib
import experiment_utils

importlib.reload(experiment_utils)

from experiment_utils import (
    MLPClassifier,
    run_one_experiment,
    run,
    save_result
)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/Processed_Project_Data/fifa_and_elo_with_ema_v2.csv")

df = df.drop(columns=["Unnamed: 0"], errors="ignore")

df["date"] = pd.to_datetime(df["date"], format="mixed")

df = df.sort_values("date").reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (1239, 49)
#         date             home_team    away_team  home_score  away_score  \
# 0 2022-01-27               Jamaica       Mexico         1.0         2.0
# 1 2022-01-27  United Arab Emirates        Syria         2.0         0.0
# 2 2022-01-27              Honduras       Canada         0.0         2.0
# 3 2022-01-27            Costa Rica       Panama         1.0         0.0
# 4 2022-01-27               Lebanon  South Korea         0.0         1.0
#
#                      tournament            city               country  \
# 0  FIFA World Cup qualification        Kingston               Jamaica
# 1  FIFA World Cup qualification           Dubai  United Arab Emirates
# 2  FIFA World Cup qualification  San Pedro Sula              Honduras
# 3  FIFA World Cup qualification        San José            Costa Rica
# 4  FIFA World Cup qualification           Sidon               Lebanon
#
#    neutral  year  ...  away_form_sma7  away_form_ema50  away_form_ema33  \
# 0        0  2022  ...             NaN              NaN              NaN
# 1        0  2022  ...             NaN              NaN              NaN
# 2        0  2022  ...             NaN              NaN              NaN
# 3        0  2022  ...             NaN              NaN              NaN
# 4        0  2022  ...             NaN              NaN              NaN
#
#   away_form_ema25  form_diff_sma3  form_diff_sma5  form_diff_sma7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    form_diff_ema50  form_diff_ema33 form_diff_ema25
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
#
# [5 rows x 49 columns]

# %%
best_sma = "sma5"

features = [
    "home_rank",
    "away_rank",
    "home_elo",
    "away_elo",
    f"home_form_{best_sma}",
    f"away_form_{best_sma}",
]

target = "result"

features
# Out:
# ['home_rank',
#  'away_rank',
#  'home_elo',
#  'away_elo',
#  'home_form_sma5',
#  'away_form_sma5']

# %%
print("Broj redova pre uklanjanja NaN vrednosti:", len(df))
print()
print("NaN vrednosti u feature kolonama:")
print(df[features].isna().sum())

df = df.dropna(subset=features + [target]).reset_index(drop=True)

print()
print("Broj redova posle uklanjanja NaN vrednosti:", len(df))
print()
print("Provera NaN vrednosti posle filtriranja:")
print(df[features].isna().sum())

df[features + [target]].head()
# Out:
# Broj redova pre uklanjanja NaN vrednosti: 1239
#
# NaN vrednosti u feature kolonama:
# home_rank           0
# away_rank           0
# home_elo            0
# away_elo            0
# home_form_sma5     98
# away_form_sma5    108
# dtype: int64
#
# Broj redova posle uklanjanja NaN vrednosti: 1110
#
# Provera NaN vrednosti posle filtriranja:
# home_rank         0
# away_rank         0
# home_elo          0
# away_elo          0
# home_form_sma5    0
# away_form_sma5    0
# dtype: int64
#    home_rank  away_rank  home_elo  away_elo  home_form_sma5  away_form_sma5  \
# 0       14.0       49.0    1839.0    1743.0             3.0             3.0
# 1       40.0       11.0    1784.0    1858.0             3.0             3.0
# 2       76.0       70.0    1604.0    1466.0             0.0             0.0
# 3       63.0       57.0    1627.0    1578.0             0.0             0.0
# 4       17.0       59.0    1847.0    1801.0             3.0             3.0
#
#    result
# 0       0
# 1       1
# 2      -1
# 3       1
# 4       1

# %%
X = df[features].values

label_map = {
    -1: 0,   # away win
     0: 1,   # draw
     1: 2    # home win
}

y = df[target].map(label_map).values

print("Label mapping:")
print("-1 -> 0  away win")
print(" 0 -> 1  draw")
print(" 1 -> 2  home win")
# Out:
# Label mapping:
# -1 -> 0  away win
#  0 -> 1  draw
#  1 -> 2  home win

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (888, 6)
# X_test: (222, 6)
# y_train: (888,)
# y_test: (222,)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_tensor = torch.tensor(
    X_train_scaled,
    dtype=torch.float32
)

y_train_tensor = torch.tensor(
    y_train,
    dtype=torch.long
)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
)

y_test_tensor = torch.tensor(
    y_test,
    dtype=torch.long
)

print("Tensor shapes:")
print("X_train_tensor:", X_train_tensor.shape)
print("y_train_tensor:", y_train_tensor.shape)
print("X_test_tensor:", X_test_tensor.shape)
print("y_test_tensor:", y_test_tensor.shape)
# Out:
# Tensor shapes:
# X_train_tensor: torch.Size([888, 6])
# y_train_tensor: torch.Size([888])
# X_test_tensor: torch.Size([222, 6])
# y_test_tensor: torch.Size([222])

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

input_dim = X_train_tensor.shape[1]

model = MLPClassifier(input_dim=input_dim)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

# %%
run_one_experiment(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
)
# Out:
# Epoch 50/1000 | train loss = 0.8556 | val loss = 0.7146 | val acc = 0.6854
# Epoch 100/1000 | train loss = 0.8403 | val loss = 0.7185 | val acc = 0.6798
# Epoch 150/1000 | train loss = 0.8392 | val loss = 0.7211 | val acc = 0.6685
# Epoch 200/1000 | train loss = 0.8218 | val loss = 0.7287 | val acc = 0.6685
# Epoch 250/1000 | train loss = 0.8044 | val loss = 0.7282 | val acc = 0.6573
# Epoch 300/1000 | train loss = 0.8189 | val loss = 0.7324 | val acc = 0.6517
# Epoch 350/1000 | train loss = 0.7902 | val loss = 0.7237 | val acc = 0.6573
# Epoch 400/1000 | train loss = 0.7787 | val loss = 0.7334 | val acc = 0.6629
# Epoch 450/1000 | train loss = 0.7823 | val loss = 0.7432 | val acc = 0.6573
# Epoch 500/1000 | train loss = 0.7563 | val loss = 0.7455 | val acc = 0.6461
# Epoch 550/1000 | train loss = 0.7834 | val loss = 0.7414 | val acc = 0.6517
# Epoch 600/1000 | train loss = 0.7719 | val loss = 0.7507 | val acc = 0.6404
# Epoch 650/1000 | train loss = 0.7493 | val loss = 0.7516 | val acc = 0.6348
# Epoch 700/1000 | train loss = 0.7621 | val loss = 0.7627 | val acc = 0.6517
# Epoch 750/1000 | train loss = 0.7342 | val loss = 0.7725 | val acc = 0.6292
# Epoch 800/1000 | train loss = 0.7601 | val loss = 0.7808 | val acc = 0.6236
# Epoch 850/1000 | train loss = 0.7366 | val loss = 0.7872 | val acc = 0.6404
# Epoch 900/1000 | train loss = 0.7244 | val loss = 0.7898 | val acc = 0.6124
# Epoch 950/1000 | train loss = 0.7193 | val loss = 0.7953 | val acc = 0.6180
# Epoch 1000/1000 | train loss = 0.7236 | val loss = 0.7952 | val acc = 0.6180
#
# =========================
# Best epoch:    66
# Best val loss: 0.7134
# Test accuracy: 0.6622
# =========================
# 0.6621621621621622

# %%
best_num_epochs = 66

summary, results_df = run(
    model_class=MLPClassifier,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
    num_runs=10,
    num_epochs=best_num_epochs,
    batch_size=16,
    learning_rate=0.001
)
# Out:
# Run 1/10
# Accuracy: 0.6622 | Precision: 0.5922 | Recall: 0.5665 | Specificity: 0.8088 | F1: 0.5391
#
# Run 2/10
# Accuracy: 0.6532 | Precision: 0.4304 | Recall: 0.5464 | Specificity: 0.8009 | F1: 0.4814
#
# Run 3/10
# Accuracy: 0.6486 | Precision: 0.5665 | Recall: 0.5431 | Specificity: 0.7941 | F1: 0.5014
#
# Run 4/10
# Accuracy: 0.6847 | Precision: 0.6810 | Recall: 0.5960 | Specificity: 0.8222 | F1: 0.5738
#
# Run 5/10
# Accuracy: 0.6892 | Precision: 0.6606 | Recall: 0.5989 | Specificity: 0.8230 | F1: 0.5839
#
# Run 6/10
# Accuracy: 0.6532 | Precision: 0.4337 | Recall: 0.5464 | Specificity: 0.7975 | F1: 0.4835
#
# Run 7/10
# Accuracy: 0.6622 | Precision: 0.6029 | Recall: 0.5604 | Specificity: 0.8073 | F1: 0.5200
#
# Run 8/10
# Accuracy: 0.6667 | Precision: 0.6280 | Recall: 0.5695 | Specificity: 0.8071 | F1: 0.5435
#
# Run 9/10
# Accuracy: 0.6577 | Precision: 0.6029 | Recall: 0.5491 | Specificity: 0.7990 | F1: 0.5062
#
# Run 10/10
# Accuracy: 0.6577 | Precision: 0.4321 | Recall: 0.5536 | Specificity: 0.8037 | F1: 0.4850
#
# =========================
# Summary over all runs
# =========================
# Accuracy:    0.6635
# Precision:   0.5630
# Recall:      0.5630
# Specificity: 0.8064
# F1 mean:     0.5218
# F1 std:      0.0372
# F1 min:      0.4814
# F1 max:      0.5839
# =========================
#
# Classification report for last run:
#               precision    recall  f1-score   support
#
#     Away Win       0.60      0.82      0.69        65
#         Draw       0.00      0.00      0.00        47
#     Home Win       0.69      0.85      0.76       110
#
#     accuracy                           0.66       222
#    macro avg       0.43      0.55      0.49       222
# weighted avg       0.52      0.66      0.58       222
#
# Confusion matrix for last run:
#                Pred Away Win  Pred Draw  Pred Home Win
# True Away Win             53          0             12
# True Draw                 18          0             29
# True Home Win             17          0             93

# %%
save_result(
    experiment_name=f"Experiment_3-1_v2_points_ranks_{best_sma.upper()}",
    summary=summary
)
# Out:
# Saved result for Experiment_3-1_v2_points_ranks_SMA5
# File: ../results/experiment_summary_final.csv
