# %%
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import importlib
import experiment_utils

importlib.reload(experiment_utils)

from experiment_utils import (
    MLPClassifier,
    run_one_experiment,
    run,
    save_result
)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/Processed_Project_Data/fifa_and_elo_with_ema_v2.csv")

df = df.drop(columns=["Unnamed: 0"], errors="ignore")

df["date"] = pd.to_datetime(df["date"], format="mixed")

df = df.sort_values("date").reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (1239, 49)
#         date             home_team    away_team  home_score  away_score  \
# 0 2022-01-27               Jamaica       Mexico         1.0         2.0
# 1 2022-01-27  United Arab Emirates        Syria         2.0         0.0
# 2 2022-01-27              Honduras       Canada         0.0         2.0
# 3 2022-01-27            Costa Rica       Panama         1.0         0.0
# 4 2022-01-27               Lebanon  South Korea         0.0         1.0
#
#                      tournament            city               country  \
# 0  FIFA World Cup qualification        Kingston               Jamaica
# 1  FIFA World Cup qualification           Dubai  United Arab Emirates
# 2  FIFA World Cup qualification  San Pedro Sula              Honduras
# 3  FIFA World Cup qualification        San José            Costa Rica
# 4  FIFA World Cup qualification           Sidon               Lebanon
#
#    neutral  year  ...  away_form_sma7  away_form_ema50  away_form_ema33  \
# 0        0  2022  ...             NaN              NaN              NaN
# 1        0  2022  ...             NaN              NaN              NaN
# 2        0  2022  ...             NaN              NaN              NaN
# 3        0  2022  ...             NaN              NaN              NaN
# 4        0  2022  ...             NaN              NaN              NaN
#
#   away_form_ema25  form_diff_sma3  form_diff_sma5  form_diff_sma7  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    form_diff_ema50  form_diff_ema33 form_diff_ema25
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
#
# [5 rows x 49 columns]

# %%
best_sma_diff = "sma5"
best_ema_diff = "ema25"

features = [
    "rank_advantage",
    "elo_advantage",
    f"form_diff_{best_sma_diff}",
    f"form_diff_{best_ema_diff}",
]

target = "result"

features
# Out:
# ['rank_advantage', 'elo_advantage', 'form_diff_sma5', 'form_diff_ema25']

# %%
print("Broj redova pre uklanjanja NaN vrednosti:", len(df))
print()
print("NaN vrednosti u feature kolonama:")
print(df[features].isna().sum())

df = df.dropna(subset=features + [target]).reset_index(drop=True)

print()
print("Broj redova posle uklanjanja NaN vrednosti:", len(df))
print()
print("Provera NaN vrednosti posle filtriranja:")
print(df[features].isna().sum())

df[features + [target]].head()
# Out:
# Broj redova pre uklanjanja NaN vrednosti: 1239
#
# NaN vrednosti u feature kolonama:
# rank_advantage       0
# elo_advantage        0
# form_diff_sma5     129
# form_diff_ema25    129
# dtype: int64
#
# Broj redova posle uklanjanja NaN vrednosti: 1110
#
# Provera NaN vrednosti posle filtriranja:
# rank_advantage     0
# elo_advantage      0
# form_diff_sma5     0
# form_diff_ema25    0
# dtype: int64
#    rank_advantage  elo_advantage  form_diff_sma5  form_diff_ema25  result
# 0            35.0           96.0             0.0              0.0       0
# 1           -29.0          -74.0             0.0              0.0       1
# 2            -6.0          138.0             0.0              0.0      -1
# 3            -6.0           49.0             0.0              0.0       1
# 4            42.0           46.0             0.0              0.0       1

# %%
X = df[features].values

label_map = {
    -1: 0,   # away win
     0: 1,   # draw
     1: 2    # home win
}

y = df[target].map(label_map).values

print("Label mapping:")
print("-1 -> 0  away win")
print(" 0 -> 1  draw")
print(" 1 -> 2  home win")
# Out:
# Label mapping:
# -1 -> 0  away win
#  0 -> 1  draw
#  1 -> 2  home win

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    shuffle=False
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (888, 4)
# X_test: (222, 4)
# y_train: (888,)
# y_test: (222,)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_tensor = torch.tensor(
    X_train_scaled,
    dtype=torch.float32
)

y_train_tensor = torch.tensor(
    y_train,
    dtype=torch.long
)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
)

y_test_tensor = torch.tensor(
    y_test,
    dtype=torch.long
)

print("Tensor shapes:")
print("X_train_tensor:", X_train_tensor.shape)
print("y_train_tensor:", y_train_tensor.shape)
print("X_test_tensor:", X_test_tensor.shape)
print("y_test_tensor:", y_test_tensor.shape)
# Out:
# Tensor shapes:
# X_train_tensor: torch.Size([888, 4])
# y_train_tensor: torch.Size([888])
# X_test_tensor: torch.Size([222, 4])
# y_test_tensor: torch.Size([222])

# %%
X_train_tensor = torch.tensor(
    X_train_scaled,
    dtype=torch.float32
)

y_train_tensor = torch.tensor(
    y_train,
    dtype=torch.long
)

X_test_tensor = torch.tensor(
    X_test_scaled,
    dtype=torch.float32
)

y_test_tensor = torch.tensor(
    y_test,
    dtype=torch.long
)

print("Tensor shapes:")
print("X_train_tensor:", X_train_tensor.shape)
print("y_train_tensor:", y_train_tensor.shape)
print("X_test_tensor:", X_test_tensor.shape)
print("y_test_tensor:", y_test_tensor.shape)
# Out:
# Tensor shapes:
# X_train_tensor: torch.Size([888, 4])
# y_train_tensor: torch.Size([888])
# X_test_tensor: torch.Size([222, 4])
# y_test_tensor: torch.Size([222])

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

input_dim = X_train_tensor.shape[1]

model = MLPClassifier(input_dim=input_dim)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001
)

# %%
run_one_experiment(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
)
# Out:
# Epoch 50/1000 | train loss = 0.8611 | val loss = 0.6977 | val acc = 0.6854
# Epoch 100/1000 | train loss = 0.8597 | val loss = 0.6996 | val acc = 0.6798
# Epoch 150/1000 | train loss = 0.8393 | val loss = 0.6956 | val acc = 0.6798
# Epoch 200/1000 | train loss = 0.8637 | val loss = 0.7054 | val acc = 0.6798
# Epoch 250/1000 | train loss = 0.8334 | val loss = 0.7065 | val acc = 0.7079
# Epoch 300/1000 | train loss = 0.8332 | val loss = 0.7059 | val acc = 0.6910
# Epoch 350/1000 | train loss = 0.8267 | val loss = 0.7073 | val acc = 0.6798
# Epoch 400/1000 | train loss = 0.8186 | val loss = 0.7214 | val acc = 0.6798
# Epoch 450/1000 | train loss = 0.8096 | val loss = 0.7246 | val acc = 0.6742
# Epoch 500/1000 | train loss = 0.8213 | val loss = 0.7238 | val acc = 0.6742
# Epoch 550/1000 | train loss = 0.7835 | val loss = 0.7223 | val acc = 0.6685
# Epoch 600/1000 | train loss = 0.7886 | val loss = 0.7295 | val acc = 0.6629
# Epoch 650/1000 | train loss = 0.8130 | val loss = 0.7427 | val acc = 0.6348
# Epoch 700/1000 | train loss = 0.7779 | val loss = 0.7458 | val acc = 0.6573
# Epoch 750/1000 | train loss = 0.7974 | val loss = 0.7475 | val acc = 0.6461
# Epoch 800/1000 | train loss = 0.7865 | val loss = 0.7477 | val acc = 0.6573
# Epoch 850/1000 | train loss = 0.7622 | val loss = 0.7468 | val acc = 0.6517
# Epoch 900/1000 | train loss = 0.7907 | val loss = 0.7532 | val acc = 0.6629
# Epoch 950/1000 | train loss = 0.7792 | val loss = 0.7489 | val acc = 0.6573
# Epoch 1000/1000 | train loss = 0.7682 | val loss = 0.7584 | val acc = 0.6404
#
# =========================
# Best epoch:    191
# Best val loss: 0.6919
# Test accuracy: 0.6486
# =========================
# 0.6486486486486487

# %%
best_num_epochs = 191

summary, results_df = run(
    model_class=MLPClassifier,
    X_train_tensor=X_train_tensor,
    y_train_tensor=y_train_tensor,
    X_test_tensor=X_test_tensor,
    y_test_tensor=y_test_tensor,
    num_runs=10,
    num_epochs=best_num_epochs,
    batch_size=16,
    learning_rate=0.001
)
# Out:
# Run 1/10
# Accuracy: 0.6486 | Precision: 0.5006 | Recall: 0.5411 | Specificity: 0.7969 | F1: 0.4915
#
# Run 2/10
# Accuracy: 0.6396 | Precision: 0.5090 | Recall: 0.5330 | Specificity: 0.7907 | F1: 0.4834
#
# Run 3/10
# Accuracy: 0.6486 | Precision: 0.5649 | Recall: 0.5452 | Specificity: 0.7958 | F1: 0.5017
#
# Run 4/10
# Accuracy: 0.6306 | Precision: 0.4747 | Recall: 0.5248 | Specificity: 0.7863 | F1: 0.4800
#
# Run 5/10
# Accuracy: 0.6351 | Precision: 0.4829 | Recall: 0.5320 | Specificity: 0.7899 | F1: 0.4837
#
# Run 6/10
# Accuracy: 0.6532 | Precision: 0.5725 | Recall: 0.5521 | Specificity: 0.7994 | F1: 0.5240
#
# Run 7/10
# Accuracy: 0.6441 | Precision: 0.5267 | Recall: 0.5441 | Specificity: 0.7982 | F1: 0.5098
#
# Run 8/10
# Accuracy: 0.6441 | Precision: 0.5458 | Recall: 0.5441 | Specificity: 0.7943 | F1: 0.5101
#
# Run 9/10
# Accuracy: 0.6532 | Precision: 0.5516 | Recall: 0.5440 | Specificity: 0.7956 | F1: 0.5049
#
# Run 10/10
# Accuracy: 0.6396 | Precision: 0.5170 | Recall: 0.5349 | Specificity: 0.7905 | F1: 0.4968
#
# =========================
# Summary over all runs
# =========================
# Accuracy:    0.6437
# Precision:   0.5246
# Recall:      0.5395
# Specificity: 0.7938
# F1 mean:     0.4986
# F1 std:      0.0142
# F1 min:      0.4800
# F1 max:      0.5240
# =========================
#
# Classification report for last run:
#               precision    recall  f1-score   support
#
#     Away Win       0.64      0.71      0.67        65
#         Draw       0.25      0.04      0.07        47
#     Home Win       0.66      0.85      0.75       110
#
#     accuracy                           0.64       222
#    macro avg       0.52      0.53      0.50       222
# weighted avg       0.57      0.64      0.58       222
#
# Confusion matrix for last run:
#                Pred Away Win  Pred Draw  Pred Home Win
# True Away Win             46          2             17
# True Draw                 14          2             31
# True Home Win             12          4             94

# %%
save_result(
    experiment_name=f"Experiment_3-6_v2_points_rank_diff_elo_diff_{best_sma_diff.upper()}{best_ema_diff.upper()}",
    summary=summary
)
# Out:
# Saved result for Experiment_3-6_v2_points_rank_diff_elo_diff_SMA5EMA25
# File: ../results/experiment_summary_final.csv
