# %% [markdown]
# # 01 — Istraživanje podataka
#
# Učitavanje i pregled sva tri dataseta: Kaggle međunarodni rezultati, football-data.co.uk kvote, Elo rejtinzi.

# %%
import pandas as pd
import sys
sys.path.append('../src')
from utils import DATA_RAW, DATA_PROCESSED
