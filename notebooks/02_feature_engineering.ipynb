# %% [markdown]
# # 02 — Feature Engineering
#
# Rolling statistike, Elo integrisanje, kreiranje finalnog feature seta. Bez data leakage.

# %%
import pandas as pd
import sys
sys.path.append('../src')
from features import *
from utils import DATA_PROCESSED
