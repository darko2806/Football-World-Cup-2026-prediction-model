# %% [markdown]
# # 05 — Predikcija SP 2026
#
# Finalne verovatnoće za sve utakmice SP 2026. Poisson matrica → P(W)/P(D)/P(L) za svaki meč.

# %%
import pandas as pd
import sys
sys.path.append('../src')
from model import *
from poisson import *
from utils import DATA_PROCESSED
