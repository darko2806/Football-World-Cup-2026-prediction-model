# %% [markdown]
# # 03 — Trening modela
#
# XGBoost regresija za lambda_home i lambda_away. Cross-validacija, tuning hiperparametara.

# %%
import pandas as pd
import sys
sys.path.append('../src')
from model import *
from utils import DATA_PROCESSED
