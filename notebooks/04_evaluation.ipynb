# %% [markdown]
# # 04 — Evaluacija
#
# Brier score vs. bookmaker baseline. Kalibracija verovatnoća, confusion matrice.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../src')
from model import *
from poisson import *
